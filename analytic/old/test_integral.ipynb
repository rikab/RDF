# %%
import jax.numpy as jnp
import numpy as np
import diffrax


fun = lambda t: t * jnp.log(1 + t)

epsabs = epsrel = 1e-5 # by default jax uses 32 bit, higher accuracy requires going to 64 bit
a, b = 0, 1
y, info = quadgk(fun, [a, b], epsabs=epsabs, epsrel=epsrel)
assert info.err < max(epsabs, epsrel*abs(y))
np.testing.assert_allclose(y, 1/4, rtol=epsrel, atol=epsabs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       8 epsabs = epsrel = 1e-5 # by default jax uses 32 bit, higher accuracy requires going to 64 bit
#       9 a, b = 0, 1
# ---> 10 y, info = quadgk(fun, [a, b], epsabs=epsabs, epsrel=epsrel)
#      11 assert info.err < max(epsabs, epsrel*abs(y))
#      12 np.testing.assert_allclose(y, 1/4, rtol=epsrel, atol=epsabs)
#
# NameError: name 'quadgk' is not defined
